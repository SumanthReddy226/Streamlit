# %%
import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv(r"D:/Sumanth/datasets/data_dictionary .csv")

# %%
df1
# Out:
#              Field Possible Values                                 Comments
# 0           fsa_id             int  Food Standard Agency's ID for this pub.
# 1             name          string                         Name of the pub.
# 2          address          string      Address fields separated by commas.
# 3         postcode          string                     Postcode of the pub.
# 4          easting             int                                      NaN
# 5         northing             int                                      NaN
# 6         latitude         decimal                                      NaN
# 7        longitude         decimal                                      NaN
# 8  local_authority          string    Local authority this pub falls under.

# %%
df2 = pd.read_csv(r"D:/Sumanth/datasets/open_pubs.csv")

# %%
df2
# Out:
#            22                                Anchor Inn  \
# 0          36                        Ark Bar Restaurant
# 1          74                                 Black Boy
# 2          75                               Black Horse
# 3          76                                Black Lion
# 4          97                              Brewers Arms
# ...       ...                                       ...
# 51325  597119  Wrexham & District War Memorial Club Ltd
# 51326  597127                 Wrexham Lager Social Club
# 51327  597130         Wrexham Rail Sports & Social Club
# 51328  597131                        Wrexham Rugby Club
# 51329  597137                                     Y Tai
#
#              Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW  604749  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH  610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA  587334
# ...

# %%
df3 = df1.T

# %%
df3
# Out:
#                                                        0                 1  \
# Field                                             fsa_id              name
# Possible Values                                      int            string
# Comments         Food Standard Agency's ID for this pub.  Name of the pub.
#
#                                                    2                     3  \
# Field                                        address              postcode
# Possible Values                               string                string
# Comments         Address fields separated by commas.  Postcode of the pub.
#
#                        4         5         6          7  \
# Field            easting  northing  latitude  longitude
# Possible Values      int       int   decimal    decimal
# Comments             NaN       NaN       NaN        NaN
#
#                                                      8
# Field                                  local_authority
# ...

# %%
df3.loc['Field']
# Out:
# 0             fsa_id
# 1               name
# 2            address
# 3           postcode
# 4            easting
# 5           northing
# 6           latitude
# 7          longitude
# 8    local_authority
# Name: Field, dtype: object

# %%
df2.columns = df3.loc['Field']

# %%
df2
# Out:
# Field  fsa_id                                      name  \
# 0          36                        Ark Bar Restaurant
# 1          74                                 Black Boy
# 2          75                               Black Horse
# 3          76                                Black Lion
# 4          97                              Brewers Arms
# ...       ...                                       ...
# 51325  597119  Wrexham & District War Memorial Club Ltd
# 51326  597127                 Wrexham Lager Social Club
# 51327  597130         Wrexham Rail Sports & Social Club
# 51328  597131                        Wrexham Rugby Club
# 51329  597137                                     Y Tai
#
# Field                                            address  postcode  easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51330 entries, 0 to 51329
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           51330 non-null  int64
#  1   name             51330 non-null  object
#  2   address          51330 non-null  object
#  3   postcode         51330 non-null  object
#  4   easting          51330 non-null  int64
#  5   northing         51330 non-null  int64
#  6   latitude         51330 non-null  object
#  7   longitude        51330 non-null  object
#  8   local_authority  51330 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 3.5+ MB

# %%
df2.replace("\\N", np.nan, inplace=True)

# %%
df2.isna().sum()
# Out:
# Field
# fsa_id               0
# name                 0
# address              0
# postcode             0
# easting              0
# northing             0
# latitude           767
# longitude          767
# local_authority      0
# dtype: int64

# %%
df2.dropna(axis=0, how='any',inplace=True)

# %%
df2['latitude']=df2['latitude'].astype(float)
df2['longitude']=df2['longitude'].astype(float)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50563 entries, 0 to 51329
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           50563 non-null  int64
#  1   name             50563 non-null  object
#  2   address          50563 non-null  object
#  3   postcode         50563 non-null  object
#  4   easting          50563 non-null  int64
#  5   northing         50563 non-null  int64
#  6   latitude         50563 non-null  float64
#  7   longitude        50563 non-null  float64
#  8   local_authority  50563 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 3.9+ MB

# %%
df2
# Out:
# Field  fsa_id                                      name  \
# 0          36                        Ark Bar Restaurant
# 1          74                                 Black Boy
# 4          97                              Brewers Arms
# 5         102                              Bristol Arms
# 6         122                           Caffeine Lounge
# ...       ...                                       ...
# 51325  597119  Wrexham & District War Memorial Club Ltd
# 51326  597127                 Wrexham Lager Social Club
# 51327  597130         Wrexham Rail Sports & Social Club
# 51328  597131                        Wrexham Rugby Club
# 51329  597137                                     Y Tai
#
# Field                                            address  postcode  easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# ...

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
# Field  index  fsa_id                                      name  \
# 0          0      36                        Ark Bar Restaurant
# 1          1      74                                 Black Boy
# 2          4      97                              Brewers Arms
# 3          5     102                              Bristol Arms
# 4          6     122                           Caffeine Lounge
# ...      ...     ...                                       ...
# 50558  51325  597119  Wrexham & District War Memorial Club Ltd
# 50559  51326  597127                 Wrexham Lager Social Club
# 50560  51327  597130         Wrexham Rail Sports & Social Club
# 50561  51328  597131                        Wrexham Rugby Club
# 50562  51329  597137                                     Y Tai
#
# Field                                            address  postcode  easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# ...

# %%
df2.drop('index',axis=1,inplace=True)

# %%
df2
# Out:
# Field  fsa_id                                      name  \
# 0          36                        Ark Bar Restaurant
# 1          74                                 Black Boy
# 2          97                              Brewers Arms
# 3         102                              Bristol Arms
# 4         122                           Caffeine Lounge
# ...       ...                                       ...
# 50558  597119  Wrexham & District War Memorial Club Ltd
# 50559  597127                 Wrexham Lager Social Club
# 50560  597130         Wrexham Rail Sports & Social Club
# 50561  597131                        Wrexham Rugby Club
# 50562  597137                                     Y Tai
#
# Field                                            address  postcode  easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# ...

# %%
df2.to_csv(r"D:/Sumanth/datasets/new_pub.csv")
